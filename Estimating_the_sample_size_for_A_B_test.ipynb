# %% [markdown]
# <a href="https://colab.research.google.com/github/KaterinaRubish/Data-analitic/blob/main/Estimating_the_sample_size_for_A_B_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import statsmodels.stats.api as sms
from statsmodels.stats.proportion import proportion_effectsize

baseline_conversion = 0.10

expected_lift = 0.03 * baseline_conversion
variant_conversion = baseline_conversion + expected_lift

effect_size = proportion_effectsize(baseline_conversion, variant_conversion)

alpha = 0.05
power = 0.80

sample_size = sms.NormalIndPower().solve_power(effect_size=effect_size, power=power, alpha=alpha, ratio=1)

print(f"Required sample size for each group: {int(np.ceil(sample_size))}")
# Out:
# Required sample size for each group: 159059

# %%
import numpy as np
import statsmodels.stats.api as sms
from statsmodels.stats.proportion import proportion_effectsize

baseline_conversion = 0.10

expected_lift = 0.03 * baseline_conversion
variant_conversion = baseline_conversion + expected_lift

effect_size = proportion_effectsize(baseline_conversion, variant_conversion)

alpha = 0.01
power = 0.80

sample_size = sms.NormalIndPower().solve_power(effect_size=effect_size, power=power, alpha=alpha, ratio=1)

print(f"Required sample size for each group: {int(np.ceil(sample_size))}")
# Out:
# Required sample size for each group: 236676

# %% [markdown]
# Якщо рівень значущості знизити до 1%, то розмір вибірки збільшується.

# %%
import numpy as np
import statsmodels.stats.api as sms
from statsmodels.stats.proportion import proportion_effectsize

baseline_conversion = 0.10

expected_lift = 0.01 * baseline_conversion
variant_conversion = baseline_conversion + expected_lift

effect_size = proportion_effectsize(baseline_conversion, variant_conversion)

alpha = 0.01
power = 0.80

sample_size = sms.NormalIndPower().solve_power(effect_size=effect_size, power=power, alpha=alpha, ratio=1)

print(f"Required sample size for each group: {int(np.ceil(sample_size))}")
# Out:
# Required sample size for each group: 2111540

# %% [markdown]
# Якщо очікуваний ефект зменшити до 1% різниці в конверсії, то розмір вибірки збільшується.
